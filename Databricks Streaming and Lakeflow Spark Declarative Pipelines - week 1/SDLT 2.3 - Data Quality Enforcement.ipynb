# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# # Data Quality Enforcement
#
# This notebook allows you to programmatically generate and trigger an update of a Lakeflow Spark Declarative pipeline that consists of the following notebooks:
#
# |Lakeflow Spark Declarative pipeline|
# |---|
# |Auto Load to Bronze|
# |Stream from Multiplex Bronze|
# |[Quality Enforcement]($./Pipeline/SDLT 2.3.1 - Data Quality Enforcement)|
#
# As we continue through the course, you can return to this notebook and use the provided methods to:
# - Land a new batch of data
# - Trigger a pipeline update
# - Process all remaining data
#
# **NOTE:** Re-running the entire notebook will delete the underlying data files for both the source data and your Lakeflow Spark Declarative pipeline.

# %% [markdown]
# ## Run Setup
# Run the following cell to reset and configure your working environment for this course.

# %% [markdown]
# ## REQUIRED - SELECT CLASSIC COMPUTE
#
# Before executing cells in this notebook, please select your classic compute cluster in the lab. Be aware that **Serverless** is enabled by default.
#
# Follow these steps to select the classic compute cluster:
#
# 1. Navigate to the top-right of this notebook and click the drop-down menu to select your cluster. By default, the notebook will use **Serverless**.
#
# 1. If your cluster is available, select it and continue to the next cell. If the cluster is not shown:
#
#     - In the drop-down, select **More**.
#
#     - In the **Attach to an existing compute resource** pop-up, select the first drop-down. You will see a unique cluster name in that drop-down. Please select that cluster.
#
# **NOTE:** If your cluster has terminated, you might need to restart it in order to select it. To do this:
#
# 1. Right-click on **Compute** in the left navigation pane and select *Open in new tab*.
#
# 1. Find the triangle icon to the right of your compute cluster name and click it.
#
# 1. Wait a few minutes for the cluster to start.
#
# 1. Once the cluster is running, complete the steps above to select your cluster.

# %%
# %run ./Includes/Classroom-Setup-03
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# <table style="width:100%">
#             <tr>
#                 <td style="white-space:nowrap; width:1em">Course Catalog:</td>
#                 <td><input type="text" value="dbacademy" style="width: 100%"></td></tr>
#             <tr>
#                 <td style="white-space:nowrap; width:1em">Your Schema:</td>
#                 <td><input type="text" value="labuser13429858_1768515742" style="width: 100%"></td></tr></table>
# Searching for files in the volume: '/Volumes/dbacademy/ops/labuser13429858_1768515742@vocareum_com/stream/daily/'.
# Deleting all files in the volume: '/Volumes/dbacademy/ops/labuser13429858_1768515742@vocareum_com/stream/daily/'.
# Table 'dbacademy.labuser13429858_1768515742.labuser13429858_1768515742.date_lookup_clone' already exists.
# Loading batch #1 to the stream...Loaded 417,276 records

# %% [markdown]
# ## Generate the Lakeflow Spark Declarative pipeline
# Run the cell below to auto-generate the pipeline using the provided configuration values. Please navigate to Pipelines under Data Engineering Section.
#
# **NOTE:** `DeclarativePipelineCreator` is a custom Python class provided in this course to simplify pipeline creation and execution. It leverages the Databricks REST API and SDK behind the scenes. While these APIs are beyond the scope of this course, you can explore the class implementation in the `./Includes/Classroom-Setup-Common` notebook if you're interested.

# %%
spark.sql("DROP TABLE IF EXISTS dbacademy.labuser13429858_1768515742.distinct_topics")
spark.sql("DROP TABLE IF EXISTS dbacademy.labuser13429858_1768515742.bronze")
spark.sql("DROP TABLE IF EXISTS dbacademy.labuser13429858_1768515742.bpm_bronze")
spark.sql("DROP TABLE IF EXISTS dbacademy.labuser13429858_1768515742.bpm_quarantine")
spark.sql("DROP TABLE IF EXISTS dbacademy.labuser13429858_1768515742.bpm_silver")
# Out:
# DataFrame[]

# %%
demo_pipeline = DeclarativePipelineCreator(
    pipeline_name=f'demo_03_pipeline_{DA.schema_name}', 
    catalog_name='dbacademy',
    schema_name=DA.schema_name,
    root_path_folder_name='Pipeline',
    source_folder_names=[
        'SDLT 2.1.1 - Auto Load to Bronze',
        'SDLT 2.2.1 - Stream from Multiplex Bronze',
        'SDLT 2.3.1 - Data Quality Enforcement'
        ],
    configuration={"source": DA.paths.stream_source, "lookup_db": DA.lookup_db},
    serverless=True
)

demo_pipeline.create_pipeline()
# Out:
# Creating the Lakeflow Declarative Pipeline 'demo_03_pipeline_labuser13429858_1768515742'.
#
# Using root folder path: /Workspace/Users/labuser13429858_1768515742@vocareum.com/databricks-streaming-and-lakeflow-spark-declarative-pipelines-en_us-2.1.2/Databricks Streaming and Lakeflow Spark Declarative Pipelines/SDLT 2 - Streaming ETL Patterns with Lakeflow Spark Declarative Pipelines/Pipeline
#
# Using source folder path(s): [{'glob': {'include': '/Workspace/Users/labuser13429858_1768515742@vocareum.com/databricks-streaming-and-lakeflow-spark-declarative-pipelines-en_us-2.1.2/Databricks Streaming and Lakeflow Spark Declarative Pipelines/SDLT 2 - Streaming ETL Patterns with Lakeflow Spark Declarative Pipelines/Pipeline/SDLT 2.1.1 - Auto Load to Bronze'}}, {'glob': {'include': '/Workspace/Users/labuser13429858_1768515742@vocareum.com/databricks-streaming-and-lakeflow-spark-declarative-pipelines-en_us-2.1.2/Databricks Streaming and Lakeflow Spark Declarative Pipelines/SDLT 2 - Streaming ETL Patterns with Lakeflow Spark Declarative Pipelines/Pipeline/SDLT 2.2.1 - Stream from Multiplex Bronze'}}, {'glob': {'include': '/Workspace/Users/labuser13429858_1768515742@vocareum.com/databricks-streaming-and-lakeflow-spark-declarative-pipelines-en_us-2.1.2/Databricks Streaming and Lakeflow Spark Declarative Pipelines/SDLT 2 - Streaming ETL Patterns with Lakeflow Spark Declarative Pipelines/Pipeline/SDLT 2.3.1 - Data Quality Enforcement'}}]
#
# Lakeflow Declarative Pipeline Creation 'demo_03_pipeline_labuser13429858_1768515742' Complete!
# {'pipeline_id': '02c6fe78-6e99-4b5a-a8d0-87bfe6eca600'}

# %% [markdown]
# ## Trigger Pipeline Run
#
# With a pipeline created, you will now run the pipeline. The initial run will take several minutes while a cluster is provisioned. Subsequent runs will be appreciably quicker.
#
# Explore the DAG - As the pipeline completes, the execution flow is graphed. With each triggered update, all newly arriving data will be processed through your pipeline. Metrics will always be reported for current run.
#
# **📌 NOTE: The pipeline may fail because the catalog used in previous pipelines is still in use. If this happens, please wait for 1–2 minutes and then rerun the pipeline.**

# %%
demo_pipeline.start_pipeline()
# Out:
# Started the pipeline run. Navigate to Jobs and Pipelines to view the pipeline.

# %% [markdown]
# ##### 📌 NOTE: Please navigate to the Jobs & Pipelines tab and ensure the pipeline has completed successfully before running further cells.

# %% [markdown]
# ## Land New Data
#
# Run the cell below to land more data in the source directory, then manually trigger another pipeline update using the UI or the cell above.

# %%
DA.daily_stream.load()
# Out:
# Loading batch #2 to the stream...Loaded 462,415 records

# %% [markdown]
# ## Process All Remaining Data
# To continuously load all remaining batches of data to the source directory, call the same load method above with the **`continuous`** parameter set to **`True`**.
#
# Trigger another update to process the remaining data.

# %%
DA.daily_stream.load(continuous=True)  # Load all remaining batches of data
demo_pipeline.start_pipeline()  # Trigger another pipeline update
# Out:
# Loading all batches to the stream...Loaded 9,962,287 records
# Started the pipeline run. Navigate to Jobs and Pipelines to view the pipeline.
# ---------------------------------------------------------------------------
# ResourceConflict                          Traceback (most recent call last)
# File <command-4536986146192496>, line 2
#       1 DA.daily_stream.load(continuous=True)  # Load all remaining batches of data
# ----> 2 demo_pipeline.start_pipeline()
#
# File <command-4536986146192527>, line 166, in DeclarativePipelineCreator.start_pipeline(self)
#     162 '''
#     163 Starts the pipeline using the attribute set from the generate_pipeline() method.
#     164 '''
#     165 print('Started the pipeline run. Navigate to Jobs and Pipelines to view the pipeline.')
# --> 166 self.workspace.pipelines.start_update(self.get_pipeline_id())
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-83a6d370-0d9e-4605-8ced-4b75c85117fa/lib/python3.12/site-packages/databricks/sdk/service/pipelines.py:3167, in PipelinesAPI.start_update(self, pipeline_id, cause, full_refresh, full_refresh_selection, refresh_selection, validate_only)
#    3164 if validate_only is not None: body['validate_only'] = validate_only
#    3165 headers = {'Accept': 'application/json', 'Content-Type': 'application/json', }
# -> 3167 res = self._api.do('POST', f'/api/2.0/pipelines/{pipeline_id}/updates', body=body, headers=headers)
#    3168 return StartUpdateResponse.from_dict(res)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-83a6d370-0d9e-4605-8ced-4b75c85117fa/lib/python3.12/site-packages/databricks/sdk/core.py:77, in ApiClient.do(self, method, path, url, query, headers, body, raw, files, data, auth, response_headers)
#      75     path = re.sub('^/api/2.0/fs/files//', '/api/2.0/fs/files/', path)
#      76     url = f"{self._cfg.host}{path}"
# ---> 77 return self._api_client.do(method=method,
#      78                            url=url,
#      79                            query=query,
#      80                            headers=headers,
#      81                            body=body,
#      82                            raw=raw,
#      83                            files=files,
#      84                            data=data,
#      85                            auth=auth,
#      86                            response_headers=response_headers)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-83a6d370-0d9e-4605-8ced-4b75c85117fa/lib/python3.12/site-packages/databricks/sdk/_base_client.py:172, in _BaseClient.do(self, method, url, query, headers, body, raw, files, data, auth, response_headers)
#     167 else:
#     168     call = retried(timeout=timedelta(seconds=self._retry_timeout_seconds),
#     169                    is_retryable=self._is_retryable,
#     170                    clock=self._clock)(self._perform)
# --> 172 response = call(method,
#     173                 url,
#     174                 query=query,
#     175                 headers=headers,
#     176                 body=body,
#     177                 raw=raw,
#     178                 files=files,
#     179                 data=data,
#     180                 auth=auth)
#     182 resp = dict()
#     183 for header in response_headers if response_headers else []:
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-83a6d370-0d9e-4605-8ced-4b75c85117fa/lib/python3.12/site-packages/databricks/sdk/retries.py:54, in retried.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      50         retry_reason = f'{type(err).__name__} is allowed to retry'
#      52 if retry_reason is None:
#      53     # raise if exception is not retryable
# ---> 54     raise err
#      56 logger.debug(f'Retrying: {retry_reason} (sleeping ~{sleep}s)')
#      57 clock.sleep(sleep + random())
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-83a6d370-0d9e-4605-8ced-4b75c85117fa/lib/python3.12/site-packages/databricks/sdk/retries.py:33, in retried.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 while clock.time() < deadline:
#      32     try:
# ---> 33         return func(*args, **kwargs)
#      34     except Exception as err:
#      35         last_err = err
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-83a6d370-0d9e-4605-8ced-4b75c85117fa/lib/python3.12/site-packages/databricks/sdk/_base_client.py:278, in _BaseClient._perform(self, method, url, query, headers, body, raw, files, data, auth)
#     276     if self._is_seekable_stream(data):
#     277         data.seek(initial_data_position)
# --> 278     raise error from None
#     280 return response
#
# ResourceConflict: An active update 'bbcfa284-fcba-4e15-957f-101d588a6f82' already exists for pipeline '02c6fe78-6e99-4b5a-a8d0-87bfe6eca600'.

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
